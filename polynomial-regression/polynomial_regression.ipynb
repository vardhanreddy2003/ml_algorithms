# %%
import numpy as np 
import pandas as pd

# %%
X=6*np.random.rand(200,1)-3
y=0.8*X**2+0.9*X+2 + np.random.randn(200, 1)

# %%
y.shape
# Out:
# (200, 1)

# %%
import matplotlib.pyplot as plt

# %%
plt.plot(X, y,".b")
plt.xlabel("X")
plt.ylabel("y")
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
from sklearn.model_selection import train_test_split

# %%
X_train,X_test,y_train,y_test = train_test_split(X,y,test_size=0.2,random_state=2)

# %%
sns.scatterplot(x=X_train[:,0],y=y_train[:,0])
# Out:
# <Axes: >

# %%
X_train.shape[1]
# Out:
# 1

# %%
X_train
# Out:
# array([[ 2.70523889],
#        [-1.4268347 ],
#        [-2.81313527],
#        [ 0.35921621],
#        [ 0.97820676],
#        [ 0.94747796],
#        [-1.2680723 ],
#        [-2.29628029],
#        [ 2.66598692],
#        [ 0.82483546],
#        [ 1.37796513],
#        [ 2.81052496],
#        [-1.56844934],
#        [-1.80866466],
#        [ 2.56184495],
#        [ 2.9587774 ],
#        [ 1.56121192],
#        [-0.87697556],
#        [-2.92691401],
#        [ 0.9810096 ],
#        [ 1.853366  ],
#        [ 1.3907448 ],
#        [ 0.83560701],
#        [-1.30534987],
#        [-2.23019892],
#        [ 0.32581133],
#        [-1.46968286],
#        [-2.95147243],
#        [-2.34776637],
#        [ 0.66478734],
#        [ 2.49955877],
#        [ 0.13157383],
#        [ 1.80907305],
#        [-0.62899047],
#        [ 2.34678431],
#        [ 1.40703798],
#        [-0.95595116],
#        [ 2.64065377],
#        [ 2.94281165],
#        [-0.58949996],
#        [-2.46408559],
# ...

# %%
X_train[:,0]
# Out:
# array([ 2.70523889, -1.4268347 , -2.81313527,  0.35921621,  0.97820676,
#         0.94747796, -1.2680723 , -2.29628029,  2.66598692,  0.82483546,
#         1.37796513,  2.81052496, -1.56844934, -1.80866466,  2.56184495,
#         2.9587774 ,  1.56121192, -0.87697556, -2.92691401,  0.9810096 ,
#         1.853366  ,  1.3907448 ,  0.83560701, -1.30534987, -2.23019892,
#         0.32581133, -1.46968286, -2.95147243, -2.34776637,  0.66478734,
#         2.49955877,  0.13157383,  1.80907305, -0.62899047,  2.34678431,
#         1.40703798, -0.95595116,  2.64065377,  2.94281165, -0.58949996,
#        -2.46408559, -2.19633805,  2.17793113, -2.46025521, -1.60793357,
#        -2.32014453, -1.66316575,  0.21613272, -0.99200563,  1.33105428,
#        -1.98001573,  0.65670042, -1.8861344 ,  2.74406821, -2.53828362,
#         2.40467835,  0.15901774, -1.18838709, -0.49431071, -0.16115117,
#         0.53016592, -2.94913919,  2.10064961,  0.48736743, -1.86322064,
# ...

# %%
from sklearn.linear_model import LinearRegression

# %%
lr=LinearRegression()

# %%
lr.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
from sklearn.metrics import r2_score

# %%
y_pred = lr.predict(X_test)
r2_score(y_test,y_pred)
# Out:
# 0.18538311652924389

# %%
from sklearn.preprocessing import PolynomialFeatures,StandardScaler

# %%
y_pred.shape
# Out:
# (40, 1)

# %%
sns.scatterplot(x=X_test[:,0],y=y_pred[:,0],label="1",color="red")
sns.scatterplot(x=X_test[:,0],y=y_test[:,0],label="2",color="blue")

plt.legend()
plt.show()

# %%
poly=PolynomialFeatures(degree=2,include_bias=True)

X_train_trans=poly.fit_transform(X_train)
X_test_trans=poly.transform(X_test)

# %%
print(X_train[0])
print(X_train_trans[0])
# Out:
# [2.70523889]
# [1.         2.70523889 7.31831744]

# %%
lr=LinearRegression()
lr.fit(X_train_trans,y_train)
# Out:
# LinearRegression()

# %%
y_pred=lr.predict(X_test_trans)

# %%
r2_score(y_test,y_pred)
# Out:
# 0.8912968660580657

# %%
sns.scatterplot(x=X_test[:,0],y=y_pred[:,0],label="1",color="red")
sns.scatterplot(x=X_test[:,0],y=y_test[:,0],label="2",color="blue")

plt.legend()
plt.show()

# %%
X_test[:,0]
# Out:
# array([ 1.608536  , -2.30983277, -2.96506314, -2.27975364,  1.26755711,
#         1.53942759, -2.10690202,  2.15256025,  1.04064213,  0.2356071 ,
#        -0.66350838,  1.27026371, -2.53879376, -1.58749564, -1.10200698,
#        -0.22214752,  2.48809668,  0.14042824,  1.70419763, -2.62430203,
#        -0.23176863, -0.05228717,  1.30608294,  1.7132816 ,  2.39270577,
#         1.80505957,  2.58218187, -1.42815298, -0.92220592,  2.80911753,
#        -2.48729635,  0.73540876, -2.57407848,  0.35787697,  2.39571816,
#         2.92041928, -1.79340634, -2.40638081,  0.95979555, -1.02130429])

# %%
sns.scatterplot(x=X_test[:,0],y=y_pred)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[272], line 1
# ----> 1 sns.scatterplot(x=X_test[:,0],y=y_pred)
#
# File c:\Users\dell\anaconda3\Lib\site-packages\seaborn\relational.py:615, in scatterplot(data, x, y, hue, size, style, palette, hue_order, hue_norm, sizes, size_order, size_norm, markers, style_order, legend, ax, **kwargs)
#     606 def scatterplot(
#     607     data=None, *,
#     608     x=None, y=None, hue=None, size=None, style=None,
#    (...)
#     612     **kwargs
#     613 ):
# --> 615     p = _ScatterPlotter(
#     616         data=data,
#     617         variables=dict(x=x, y=y, hue=hue, size=size, style=style),
#     618         legend=legend
#     619     )
#     621     p.map_hue(palette=palette, order=hue_order, norm=hue_norm)
#     622     p.map_size(sizes=sizes, order=size_order, norm=size_norm)
#
# ...
