# %%
import numpy as np 
import pandas as pd

# %%
df=pd.read_csv("C:/Users/dell/Desktop/ml-algorithms/kmeans/student_clustering.csv")

# %%
df.head()
# Out:
#    cgpa   iq
# 0  5.13   88
# 1  5.90  113
# 2  8.36   93
# 3  8.27   97
# 4  5.45  110

# %%
import matplotlib.pyplot as plt 
import seaborn as sns

# %%
sns.scatterplot(x="cgpa",y="iq",data=df)
# Out:
# <Axes: xlabel='cgpa', ylabel='iq'>

# %%
from sklearn.cluster import KMeans

# %%
wcss=[]

for i in range(1,11):
    km=KMeans(n_clusters=i)
    km.fit_predict(df)
    wcss.append(km.inertia_)
# Out:
# c:\Users\dell\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1446: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(
# c:\Users\dell\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1446: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(
# c:\Users\dell\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1446: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(
# ...

# %%
wcss
# Out:
# [29957.898288,
#  4184.14127,
#  2503.397581,
#  681.96966,
#  614.6075962594418,
#  536.3721110469572,
#  368.0483885722135,
#  278.29151101456546,
#  214.0979617496262,
#  210.6282491179788]

# %%
plt.plot(range(1,11),wcss)

# %%
X=df.iloc[:,:].values
km=KMeans(n_clusters=4)
y_means=km.fit_predict(X)
# Out:
# c:\Users\dell\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1446: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(

# %%
y_means
# Out:
# array([1, 0, 2, 2, 0, 0, 2, 3, 0, 2, 1, 0, 2, 1, 0, 2, 0, 2, 0, 0, 2, 1,
#        2, 1, 1, 2, 1, 3, 2, 0, 3, 0, 3, 0, 2, 2, 3, 0, 1, 0, 1, 2, 2, 1,
#        3, 3, 2, 0, 3, 0, 1, 1, 3, 2, 3, 0, 0, 3, 0, 3, 0, 2, 2, 3, 1, 3,
#        2, 1, 0, 2, 0, 3, 2, 1, 0, 3, 0, 3, 1, 2, 2, 3, 0, 1, 3, 1, 3, 0,
#        3, 0, 3, 3, 2, 1, 2, 2, 3, 2, 1, 3, 0, 1, 1, 3, 1, 1, 2, 1, 3, 3,
#        2, 3, 0, 0, 2, 3, 2, 0, 3, 1, 1, 0, 2, 3, 2, 1, 2, 0, 1, 2, 2, 0,
#        1, 1, 0, 3, 0, 1, 2, 2, 2, 1, 0, 1, 1, 3, 1, 3, 0, 1, 3, 1, 3, 3,
#        1, 2, 0, 3, 0, 2, 1, 3, 0, 2, 3, 1, 0, 1, 1, 3, 3, 0, 3, 1, 1, 2,
#        3, 0, 1, 3, 3, 0, 0, 0, 2, 1, 2, 2, 3, 0, 2, 2, 1, 1, 2, 1, 3, 0,
#        0, 3])

# %%
X[y_means==3,1]
# Out:
# array([115., 119., 117., 118., 118., 116., 116., 119., 116., 115., 115.,
#        117., 118., 113., 116., 118., 117., 121., 116., 117., 117., 117.,
#        114., 118., 118., 119., 118., 118., 117., 118., 117., 119., 118.,
#        118., 117., 117., 117., 116., 118., 119., 117., 119., 120., 117.,
#        115., 115., 117., 116., 118., 117.])

# %%
sns.scatterplot(x=X[y_means==0,0],y=X[y_means==0,1],color="blue")
sns.scatterplot(x=X[y_means==1,0],y=X[y_means==1,1],color="red")
sns.scatterplot(x=X[y_means==2,0],y=X[y_means==2,1],color="green")
sns.scatterplot(x=X[y_means==3,0],y=X[y_means==3,1],color="yellow")
# Out:
# <Axes: >
